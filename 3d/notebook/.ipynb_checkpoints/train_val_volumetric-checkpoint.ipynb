# %%
import numpy as np
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import cv2
import random
from model_basic import *
from image import ImageDataGenerator
import os

from keras.models import Sequential
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.optimizers import RMSprop, Adadelta
from keras.layers.convolutional import Convolution2D
from keras.layers.core import Dense, Activation, TimeDistributedDense, Dropout, Reshape, Flatten
from keras.layers.wrappers import TimeDistributed
from keras.models import model_from_json


print 'All libs successfully loaded!'
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)
# All libs successfully loaded!

# %%
# path to data
path2set="../dcom/TrainingSet/"
path2numpy = path2set+"numpy/"
path2nfolds=path2numpy+'nfolds/'
foldnm=1

# %%
# load data
def load_data(path):
    print ('_' *50)
    print 'please wait to load data ...'
    start_time=time.time()
    tmp = np.load(path)
    X=tmp['X']
    Y=tmp['Y'] 
    print ('X shape: ', X.shape)
    print ('Y shape: ',Y.shape)
    print ('Min and Max X: ', np.min(X), np.max(X))
    print ('Min and Max Y: ', np.min(Y), np.max(Y))
    elapsed_time=time.time()-start_time
    print 'Elapsed time: %d seconds' % elapsed_time
    print ('_' *50)
    return X,Y

def grays_to_RGB(img):
    # turn 2D grayscale image into grayscale RGB
    return np.dstack((img, img, img))

def image_with_mask(img, mask):
    maximg=np.max(img)
    mask=np.asarray(mask,dtype='uint8')
    if np.max(mask)<=1:
        mask=mask*255
    # returns a copy of the image with edges of the mask added in red
    img_color = grays_to_RGB(img)
    mask_edges = cv2.Canny(mask, 100, 200) > 0
    #print np.sum(mask_edges)
    img_color[mask_edges, 0] = maximg  # set channel 0 to bright red, green & blue channels to 0
    img_color[mask_edges, 1] = 0
    img_color[mask_edges, 2] = 0
    img_color=img_color/float(np.max(img))
    return img_color

# 5D array image display
def disp_img_mask(img,mask=None,ind=None):
    # img and mask are 5d arrays, N*time*C*H*W
    img=np.squeeze(img)
    
    # check for random dispaly or based on input
    if ind is None:
        n1=np.random.randint(img.shape[0])
    else:
        n1=ind
        
    I1=img[n1,:]
    print I1.shape
    
    if mask is None:
        M1=np.zeros(I1.shape,dtype='uint8')
    else:
        mask=np.squeeze(mask)
        M1=mask[n1,:]
    print M1.shape
    
    r,c=2,5
    for k in range(r*c):
        plt.subplot(r,c,k+1)
        imgmask=image_with_mask(I1[k,:],M1[k,:])
        plt.imshow(imgmask)
        plt.title('s: %s, maxI: %s' %(n1,np.max(I1[k,:])))
    plt.show()
        
# preprocess
def preprocess(X,Y,param_prep):
    
    # get params
    h=param_prep['img_rows']
    w=param_prep['img_cols']    
    crop=param_prep['crop']
    imr=param_prep['resize_factor'] # image resize
    norm_ena=param_prep['norm_ena'] # normalization 
    
    print ('_' *50)
    start_time=time.time()
    Y=np.asarray(Y,dtype='uint8')
    # center crop h*w
    if crop is 'center':
        H,W=X.shape[2:]
        hc=(H-h)/2
        wc=(W-w)/2
        X=X[:,:,hc:H-hc,wc:W-wc]
        Y = Y[:,:,hc:H-hc,wc:W-wc]
    elif crop is 'random':
        H,W=X.shape[2:]
        hc=(H-h)/2
        wc=(W-w)/2
        hcr=np.random.randint(hc)
        wcr=np.random.randint(wc)
        X=X[:,:,hc:H-hc,wc:W-wc]
        Y = Y[:,:,hc:H-hc,wc:W-wc]
        
    print ('X shape: ', X.shape)
    print ('Y shape: ',Y.shape)

    print 'please wait to resize images ...'
    if imr<1:
        img_h=int(X.shape[2]*imr) # rows
        img_w=int(X.shape[3]*imr) # columns
        X_r=np.zeros([X.shape[0],1,img_h,img_w],dtype=X.dtype)
        Y_r=np.zeros([Y.shape[0],1,img_h,img_w],dtype=Y.dtype)
        for k1 in range(len(X)):
            X_r[k1, 0] = cv2.resize(X[k1, 0], (img_w, img_h), interpolation=cv2.INTER_CUBIC)
            Y_r[k1, 0] = cv2.resize(Y[k1, 0], (img_w, img_h), interpolation=cv2.INTER_CUBIC)
    else:
        X_r=X
        Y_r=Y
    
    # normalization
    if norm_ena is True:
        X_r=np.array(X_r,dtype='float32')
        for k in range(X_r.shape[0]):
            for m in range(X_r.shape[1]):
                mean = np.mean(X_r[k,m,0])  # mean       
                sigma = np.std(X_r[k,m,0])  # std
                if sigma<1e-5:
                    sigma=1
                X_r[k,m,:,:] = X_r[k,m,:,:]-mean
                X_r[k,m,:,:] = X_r[k,m,:,:]/ sigma

    print ('X_r size: ', X_r.shape)
    print ('Y_r size: ',Y_r.shape)
    print ('Min and Max  X_r: ', np.min(X_r), np.max(X_r))
    print ('Min and Max  Y_r: ',  np.min(Y_r),  np.max(Y_r))        
        
    # add time dimension
    X_r=np.expand_dims(X_r,axis=2)
    Y_r=np.expand_dims(Y_r,axis=2)
    
    print ('X_r size: ', X_r.shape)
    print ('Y_r size: ',Y_r.shape)
    print ('Min and Max  X_r: ', np.min(X_r), np.max(X_r))
    print ('Min and Max  Y_r: ',  np.min(Y_r),  np.max(Y_r))

    elapsed_time=time.time()-start_time
    print 'Elapsed time: %d seconds' % elapsed_time
    print ('_' *50)
    return X_r,Y_r

# convert mask to volumes
def mask2volume(Y,h=1):
    
    # number of dataset
    N1=Y.shape[0]
    
    # number of slices
    N2=Y.shape[1]
    
    V=np.zeros(N1)
    for k in range(N1):
        Vz=0
        for z in range(N2-1):
            Yz=Y[k,z,:]
            Yzp1=Y[k,z+1,:]
            Az=np.sum(Yz)
            Azp1=np.sum(Yzp1)
            Vz=Vz+.5*(Az+Azp1)
        V[k]=Vz*h            
    
    Vn=V/np.max(V)
    return V,Vn

# random data generator
datagen = ImageDataGenerator(featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=75,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.0,
        zoom_range=0,
        channel_shift_range=0.0,
        fill_mode='nearest',
        cval=0.0,
        horizontal_flip=True,
        vertical_flip=True,
        dim_ordering='th')
        
def iterate_minibatches(inputs1 , targets,  batchsize, shuffle=False, augment=True):
    assert len(inputs1) == len(targets)
 
    if shuffle is True:
        indices = np.arange(len(inputs1))
        np.random.shuffle(indices)
        print 'shuffled!'
    for start_idx in range(0, len(inputs1) - batchsize + 1, batchsize):
        if shuffle is True:
            excerpt = indices[start_idx:start_idx + batchsize]
            print 'shuffled!'
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        x = inputs1[excerpt]
        y = targets[excerpt] 
        for  xxt,yyt in datagen.flow(x, y , batch_size=x.shape[0]):
            x = xxt.astype(np.float32) 
            y = yyt 
            break

    #yield x, np.array(y, dtype=np.uint8)         
    return x, np.array(y, dtype=np.uint8)

# %%
# load train data
X_train,Y_train=load_data(path2nfolds + 'trainfold'+str(foldnm)+'.npz')

# load test data
X_test,Y_test=load_data(path2nfolds + 'testfold'+str(foldnm)+'.npz')
# Out:
# __________________________________________________
# please wait to load data ...
# ('X shape: ', (24, 10, 256, 216))
# ('Y shape: ', (24, 10, 256, 216))
# ('Min and Max X: ', 0, 1197)
# ('Min and Max Y: ', False, True)
# Elapsed time: 0 seconds
# __________________________________________________
# __________________________________________________
# please wait to load data ...
# ('X shape: ', (8, 10, 256, 216))
# ('Y shape: ', (8, 10, 256, 216))
# ('Min and Max X: ', 0, 1060)
# ('Min and Max Y: ', False, True)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
# display sample image
plt.figure(figsize=(20,10)) 
disp_img_mask(X_train,Y_train)
# Out:
# (10, 256, 216)
# (10, 256, 216)

# %%
# pre-processing 

param_prep={
    'img_rows': 192,
    'img_cols': 192,
    'crop'    : 'center',
    'resize_factor': 1,
    'norm_ena' : True,
}

# preprocess train data
X_train_r,Y_train_r=preprocess(X_train,Y_train,param_prep)

# preprocess test data
X_test_r,Y_test_r=preprocess(X_test,Y_test,param_prep)
# Out:
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -1.4170325, 19.443384)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -1.4170325, 19.443384)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# __________________________________________________
# ('X shape: ', (8, 10, 192, 192))
# ('Y shape: ', (8, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (8, 10, 192, 192))
# ('Y_r size: ', (8, 10, 192, 192))
# ('Min and Max  X_r: ', -2.5976481, 185.71657)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (8, 10, 1, 192, 192))
# ('Y_r size: ', (8, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.5976481, 185.71657)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
# display sample image
plt.figure(figsize=(20,10)) 
disp_img_mask(X_train_r,Y_train_r)

plt.figure(figsize=(20,10)) 
disp_img_mask(X_test_r,Y_test_r)
# Out:
# (10, 192, 192)
# (10, 192, 192)
# (10, 192, 192)
# (10, 192, 192)

# %%
# labels to volumes
v_train,y_train=mask2volume(Y_train)
v_test,y_test=mask2volume(Y_test)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(v_train,30)
plt.hist(v_test,10)

plt.subplot(1,2,2)
plt.hist(y_train,30)
plt.hist(y_test,10)
plt.title('normalized')
plt.show()

# %%
# define some run parameters
batch_size      = 1
nb_epochs       = 20
examplesPer     = X_train_r.shape[0]
timestep        = X_train_r.shape[1]
hidden_units    = 200
h,w= X_train_r.shape[3:5]

#define our time-distributed setup
model = Sequential()

model.add(TimeDistributed(Convolution2D(16, 3, 3, border_mode='valid',activation='relu'), input_shape=(timestep,1,h,w)))
model.add(TimeDistributed(Convolution2D(16, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2),border_mode='valid')))

model.add(TimeDistributed(Convolution2D(32, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(Convolution2D(32, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2),border_mode='valid')))

model.add(TimeDistributed(Convolution2D(64, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(Convolution2D(64, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2),border_mode='valid')))

model.add(TimeDistributed(Convolution2D(128, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(Convolution2D(128, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2),border_mode='valid')))

model.add(TimeDistributed(Convolution2D(256, 3, 3, border_mode='valid',activation='relu')))
model.add(TimeDistributed(Convolution2D(256, 3, 3, border_mode='valid',activation='relu')))

model.add(TimeDistributed(Flatten()))
model.add(Activation('relu'))
model.add(GRU(output_dim=100,return_sequences=False))
#model.add(GRU(output_dim=50,return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(1))

rmsprop = RMSprop()
model.compile(loss='mean_squared_error', optimizer=rmsprop)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# timedistributed_1 (TimeDistribute(None, 10, 16, 190, 19160         timedistributed_input_1[0][0]
# ____________________________________________________________________________________________________
# timedistributed_2 (TimeDistribute(None, 10, 16, 188, 182320        timedistributed_1[0][0]
# ____________________________________________________________________________________________________
# timedistributed_3 (TimeDistribute(None, 10, 16, 94, 94)0           timedistributed_2[0][0]
# ____________________________________________________________________________________________________
# timedistributed_4 (TimeDistribute(None, 10, 32, 92, 92)4640        timedistributed_3[0][0]
# ____________________________________________________________________________________________________
# timedistributed_5 (TimeDistribute(None, 10, 32, 90, 90)9248        timedistributed_4[0][0]
# ____________________________________________________________________________________________________
# timedistributed_6 (TimeDistribute(None, 10, 32, 45, 45)0           timedistributed_5[0][0]
# ____________________________________________________________________________________________________
# timedistributed_7 (TimeDistribute(None, 10, 64, 43, 43)18496       timedistributed_6[0][0]
# ____________________________________________________________________________________________________
# timedistributed_8 (TimeDistribute(None, 10, 64, 41, 41)36928       timedistributed_7[0][0]
# ____________________________________________________________________________________________________
# timedistributed_9 (TimeDistribute(None, 10, 64, 20, 20)0           timedistributed_8[0][0]
# ____________________________________________________________________________________________________
# timedistributed_10 (TimeDistribut(None, 10, 128, 18, 1873856       timedistributed_9[0][0]
# ____________________________________________________________________________________________________
# timedistributed_11 (TimeDistribut(None, 10, 128, 16, 16147584      timedistributed_10[0][0]
# ____________________________________________________________________________________________________
# timedistributed_12 (TimeDistribut(None, 10, 128, 8, 8) 0           timedistributed_11[0][0]
# ____________________________________________________________________________________________________
# timedistributed_13 (TimeDistribut(None, 10, 256, 6, 6) 295168      timedistributed_12[0][0]
# ____________________________________________________________________________________________________
# timedistributed_14 (TimeDistribut(None, 10, 256, 4, 4) 590080      timedistributed_13[0][0]
# ____________________________________________________________________________________________________
# timedistributed_15 (TimeDistribut(None, 10, 4096)      0           timedistributed_14[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 10, 4096)      0           timedistributed_15[0][0]
# ____________________________________________________________________________________________________
# gru_1 (GRU)                      (None, 500)           6895500     activation_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 500)           0           gru_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             501         dropout_1[0][0]
# ====================================================================================================
# Total params: 8074481
# ____________________________________________________________________________________________________

# %%
print 'train in progress ...'

if  not os.path.exists('./output/weights'):
    os.makedirs('./output/weights')
    print 'weights folder created'
filepath="./output/weights/fold"+str(foldnm)+"-volume_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only='True',mode='min')


param_prep={
    'img_rows': 192,
    'img_cols': 192,
    'crop'    : 'center',
    'resize_factor': 1,
    'norm_ena' : True,
}


# Fit the model
# number of epochs
nb_epoch=500
start_time=time.time()
score_train=[]
score_test=[]

for epoch in range(nb_epoch):
    print '-'*50
    print 'epoch: %s' %epoch
    seed = np.random.randint(0, 999999)

    # augment training
    Xaug,Yaug=iterate_minibatches( X_train, Y_train , X_train.shape[0], shuffle=False)
    X_train_aug,Y_train_aug=preprocess(Xaug,Yaug,param_prep)
    _,y_train_aug=mask2volume(Y_train_aug)
    #X_train_aug=X_train_r
    #disp_img_mask(X_train_aug,Y_train_aug)
    
    model.fit(X_train_aug, y_train_aug, validation_data=(X_test_r, y_test),nb_epoch=1, batch_size=1,verbose=0,shuffle=True,callbacks=[checkpoint])
    
    s_train=model.evaluate(X_train_aug, y_train,verbose=0)
    s_test=model.evaluate(X_test_r, y_test,verbose=0)
    print 'train: %.5f' %s_train    
    print 'test: %.5f' %s_test

    score_train=np.append(score_train,s_train)
    score_test=np.append(score_test,s_test)    

plt.plot(score_train)
plt.plot(score_test)
# Out:
# train in progress ...
# --------------------------------------------------
# epoch: 0
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -10.636099, 172.45396)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -10.636099, 172.45396)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss improved from inf to 0.16701, saving model to ./output/weights/fold1-volume_weights.hdf5
# train: 0.09527
# test: 0.16701
# --------------------------------------------------
# epoch: 1
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -8.5947218, 63.595348)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -8.5947218, 63.595348)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss improved from 0.16701 to 0.09571, saving model to ./output/weights/fold1-volume_weights.hdf5
# train: 0.09003
# test: 0.09571
# --------------------------------------------------
# epoch: 2
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.4734862, 219.93269)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.4734862, 219.93269)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.14379
# test: 0.12421
# --------------------------------------------------
# epoch: 3
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -7.3778801, 254.28156)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -7.3778801, 254.28156)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss improved from 0.09571 to 0.08231, saving model to ./output/weights/fold1-volume_weights.hdf5
# train: 0.07405
# test: 0.08231
# --------------------------------------------------
# epoch: 4
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0288262, 250.81117)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0288262, 250.81117)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.12270
# test: 0.13255
# --------------------------------------------------
# epoch: 5
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0708115, 225.91974)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0708115, 225.91974)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06787
# test: 0.09732
# --------------------------------------------------
# epoch: 6
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.2764902, 24.623867)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.2764902, 24.623867)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.13703
# test: 0.17952
# --------------------------------------------------
# epoch: 7
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.3082631, 128.10822)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.3082631, 128.10822)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss improved from 0.08231 to 0.07541, saving model to ./output/weights/fold1-volume_weights.hdf5
# train: 0.06684
# test: 0.07541
# --------------------------------------------------
# epoch: 8
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -7.082499, 235.9447)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -7.082499, 235.9447)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.17217
# test: 0.14469
# --------------------------------------------------
# epoch: 9
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.3907721, 303.74802)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.3907721, 303.74802)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06568
# test: 0.08900
# --------------------------------------------------
# epoch: 10
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -12.358499, 268.3566)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -12.358499, 268.3566)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.40824
# test: 0.44417
# --------------------------------------------------
# epoch: 11
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.6182566, 226.46478)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.6182566, 226.46478)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.07747
# test: 0.11144
# --------------------------------------------------
# epoch: 12
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -4.2611227, 231.72252)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -4.2611227, 231.72252)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.17254
# test: 0.17882
# --------------------------------------------------
# epoch: 40
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.5318928, 51.341908)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.5318928, 51.341908)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06038
# test: 0.08139
# --------------------------------------------------
# epoch: 41
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.7006814, 343.04895)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.7006814, 343.04895)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.10532
# test: 0.13071
# --------------------------------------------------
# epoch: 42
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.7176182, 344.01929)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.7176182, 344.01929)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.13050
# test: 0.16642
# --------------------------------------------------
# epoch: 43
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -15.435272, 123.72628)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -15.435272, 123.72628)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.11002
# test: 0.12686
# --------------------------------------------------
# epoch: 44
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.6864381, 319.37177)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.6864381, 319.37177)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.38759
# test: 0.38079
# --------------------------------------------------
# epoch: 45
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.78724, 29.601707)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.78724, 29.601707)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.05490
# test: 0.08660
# --------------------------------------------------
# epoch: 46
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.2827163, 249.6981)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.2827163, 249.6981)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.07461
# test: 0.10297
# --------------------------------------------------
# epoch: 47
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.6451612, 309.63449)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.6451612, 309.63449)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.14551
# test: 0.19714
# --------------------------------------------------
# epoch: 48
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.3755918, 238.94402)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.3755918, 238.94402)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.08104
# test: 0.09876
# --------------------------------------------------
# epoch: 49
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.9594882, 215.5459)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.9594882, 215.5459)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06518
# test: 0.09876
# --------------------------------------------------
# epoch: 50
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -4.4347563, 141.66986)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -4.4347563, 141.66986)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.07561
# test: 0.09085
# --------------------------------------------------
# epoch: 51
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0468175, 244.38882)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0468175, 244.38882)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.07238
# test: 0.08871
# --------------------------------------------------
# epoch: 52
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -6.8584409, 391.85681)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -6.8584409, 391.85681)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.15769
# test: 0.21126
# --------------------------------------------------
# epoch: 53
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -4.4354525, 21.464096)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -4.4354525, 21.464096)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06507
# test: 0.09966
# --------------------------------------------------
# epoch: 54
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.735327, 44.530785)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.735327, 44.530785)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.08184
# test: 0.13890
# --------------------------------------------------
# epoch: 55
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.3569355, 129.81894)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.3569355, 129.81894)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.10827
# test: 0.15619
# --------------------------------------------------
# epoch: 56
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -9.5543823, 179.00362)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -9.5543823, 179.00362)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06961
# test: 0.08346
# --------------------------------------------------
# epoch: 57
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.7808123, 49.339844)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.7808123, 49.339844)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.16216
# test: 0.11379
# --------------------------------------------------
# epoch: 58
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0114813, 333.59015)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0114813, 333.59015)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.10857
# test: 0.07956
# --------------------------------------------------
# epoch: 59
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.504359, 36.930866)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.504359, 36.930866)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss improved from 0.07541 to 0.05965, saving model to ./output/weights/fold1-volume_weights.hdf5
# train: 0.08423
# test: 0.05965
# --------------------------------------------------
# epoch: 60
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -4.1625509, 319.29187)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -4.1625509, 319.29187)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.09692
# test: 0.06868
# --------------------------------------------------
# epoch: 61
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.9022162, 121.13144)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.9022162, 121.13144)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.29228
# test: 0.31078
# --------------------------------------------------
# epoch: 62
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.5247407, 258.93057)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.5247407, 258.93057)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06729
# test: 0.08332
# --------------------------------------------------
# epoch: 63
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.5598423, 300.53458)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.5598423, 300.53458)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06593
# test: 0.07776
# --------------------------------------------------
# epoch: 64
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0469489, 51.416706)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0469489, 51.416706)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.12051
# test: 0.15886
# --------------------------------------------------
# epoch: 65
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.2684009, 166.52318)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3

# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.1907616, 282.38254)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.05526
# test: 0.08693
# --------------------------------------------------
# epoch: 495
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.266516, 421.69043)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.266516, 421.69043)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06749
# test: 0.07947
# --------------------------------------------------
# epoch: 496
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -2.6360867, 413.74344)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -2.6360867, 413.74344)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.17442
# test: 0.24340
# --------------------------------------------------
# epoch: 497
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -13.454093, 350.71063)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -13.454093, 350.71063)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.05900
# test: 0.09244
# --------------------------------------------------
# epoch: 498
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -3.0852599, 48.922272)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -3.0852599, 48.922272)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.06348
# test: 0.10060
# --------------------------------------------------
# epoch: 499
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -12.74464, 244.62189)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -12.74464, 244.62189)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Epoch 00000: val_loss did not improve
# train: 0.14834
# test: 0.12938

# %%
weights_path="./output/weights/fold"+str(foldnm)+"-volume_weights.hdf5"
print weights_path
model.load_weights(weights_path)

s_train=model.evaluate(X_train_aug, y_train_aug,verbose=0)
s_test=model.evaluate(X_test_r, y_test,verbose=0)
print 'train: %.5f' %s_train    
print 'test: %.5f' %s_test

y_pred1=model.predict(X_train_aug)
#y_pred1=np.reshape(y_pred1,(1,y_pred1.shape[0]))
y_pred2=model.predict(X_test_r)
v_train,_=mask2volume(Y_train_aug)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(v_train)
y_pred1=np.max(v_train)*y_pred1
plt.plot(y_pred1)
plt.title('train')

plt.subplot(1,2,2)
v_test,_=mask2volume(Y_test)
y_pred2=np.max(v_test)*y_pred2
plt.plot(v_test)
plt.plot(y_pred2)
plt.title('test')
plt.legend('ground truth','automatic',loc='upper right')
plt.show()
# Out:
# ./output/weights/fold1-volume_weights.hdf5
# train: 0.08687
# test: 0.05965

# %%
xaug,yaug=iterate_minibatches( X_train, Y_train , X_train.shape[0], shuffle=False)
Xaug,Yaug=preprocess(xaug,yaug,param_prep)
print np.max(xaug)
# display sample image
plt.figure(figsize=(20,10)) 
disp_img_mask(Xaug,Yaug)

vaug,vaugn=mask2volume(Yaug)
print vaug,vaugn
# Out:
# __________________________________________________
# ('X shape: ', (24, 10, 192, 192))
# ('Y shape: ', (24, 10, 192, 192))
# please wait to resize images ...
# ('X_r size: ', (24, 10, 192, 192))
# ('Y_r size: ', (24, 10, 192, 192))
# ('Min and Max  X_r: ', -5.9630866, 322.61008)
# ('Min and Max  Y_r: ', 0, 1)
# ('X_r size: ', (24, 10, 1, 192, 192))
# ('Y_r size: ', (24, 10, 1, 192, 192))
# ('Min and Max  X_r: ', -5.9630866, 322.61008)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# 1172.0
# (10, 192, 192)
# (10, 192, 192)
# [ 14068.5  29331.5  33174.5  17481.   12943.5  12909.5  22758.   19349.5
#   15802.5   8286.   15160.   25278.    7830.5  13101.5  16335.   29733.5
#    8252.5  29628.   22209.5  25004.    6934.5  17393.   28841.5   6857. ] [ 0.42407572  0.88415801  1.          0.52694087  0.39016413  0.38913925
#   0.68600883  0.58326425  0.47634478  0.24977015  0.4569775   0.76197079
#   0.23603973  0.39492683  0.49239627  0.89627575  0.24876034  0.8930956
#   0.66947505  0.75371143  0.20903103  0.52428823  0.86938763  0.2066949 ]
