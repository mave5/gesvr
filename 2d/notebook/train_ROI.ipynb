# %%
# train validation

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline  
import cv2

from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import time
from funcs import models as models
import os
print 'All libs successfully loaded!'
from funcs.image import ImageDataGenerator
from funcs import utils
from funcs import misc

# current working directory
#print os.getcwd() 

path2set="../dcom/TrainingSet/"
path2numpy = path2set+"numpy/"
path2nfolds=path2numpy+'nfolds/'
foldnm=1

# fix random seed for reproducibility
seed = 2016
np.random.seed(seed)

# configure plotting
plt.rcParams['figure.figsize'] = (15, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# Out:
# Using Theano backend.
# All libs successfully loaded!
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)

# %%
# load train data
X_train,Y_train=misc.load_data(path2nfolds + 'trainfold'+str(foldnm)+'.npz')


n1=misc.disp_img_mask(X_train,Y_train,2,4,2)
# Out:
# __________________________________________________
# please wait to load data ...
# ('X shape: ', (256, 216, 186))
# ('Y shape: ', (256, 216, 186))
# ('Min and Max X: ', 0, 1197)
# ('Min and Max Y: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
misc.disp_hist(X_train,n1,2,4,2)

# %%
# load test data
X_test,Y_test=misc.load_data(path2nfolds + 'testfold'+str(foldnm)+'.npz')

n2=misc.disp_img_mask(X_test,Y_test,2,4,2)
# Out:
# __________________________________________________
# please wait to load data ...
# ('X shape: ', (256, 216, 57))
# ('Y shape: ', (256, 216, 57))
# ('Min and Max X: ', 0, 1060)
# ('Min and Max Y: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
misc.disp_hist(X_train,n2,2,4,2)

# %%
# preprocess train data     
params_preprocess={
    'row' : 208,
    'col' :208,
    'imr' : .25,
    'crop': True,
    'crop_type': 'random',
    'normalization':True,
    }

# pre processing 
X_train_r,Y_train_r=misc.preprocess(X_train,Y_train,params_preprocess)

# display sample image
n1=misc.disp_img_mask(X_train_r,Y_train_r,2,4)
# Out:
# __________________________________________________
# __________________________________________________
# please wait ...
# Elapsed time: 0 seconds
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4263605, 8.133688)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
misc.disp_hist(X_train_r,n1,2,4,0)

# %%
# preprocess test data     
params_preprocess={
    'row' : 208,
    'col' : 208,
    'imr' : .25,
    'crop': True,
    'crop_type': 'center',
    'normalization':True,
    }

# preprocess test data
X_test_r,Y_test_r=misc.preprocess(X_test,Y_test,params_preprocess)

# display sample image
n2=misc.disp_img_mask(X_test_r,Y_test_r,2,4)
# Out:
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (57, 1, 52, 52))
# ('Y_r size: ', (57, 1, 52, 52))
# ('Min and Max  X_r: ', -1.3966141, 10.681931)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________

# %%
misc.disp_hist(X_test_r,n2,2,4,0)

# %%
# training params
params_train={
        'row': X_train_r.shape[2],
        'col': X_train_r.shape[3],           
        'weights': None,        
        'lr': 1e-4,
        'optimizer': 'Adam',
        'loss': 'mean_squared_error',
        'nbepoch': 200
        }

# build the model
model = models.model_roi(params_train)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_1 (Convolution2D)  (None, 32, 50, 50)    320         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 32, 25, 25)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 32, 25, 25)    0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 20000)         0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 2)             40002       flatten_1[0][0]
# ====================================================================================================
# Total params: 40322
# ____________________________________________________________________________________________________

# %%
# random data generator
datagen = ImageDataGenerator(featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=75,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.05,
        zoom_range=0.01,
        channel_shift_range=0.0,
        fill_mode='nearest',
        cval=0.0,
        horizontal_flip=True,
        vertical_flip=True,
        dim_ordering='th') 

def iterate_minibatches(inputs1 , targets,  batchsize, shuffle=True, augment=True):
    assert len(inputs1) == len(targets)
 
    if shuffle:
        indices = np.arange(len(inputs1))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs1) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        x = inputs1[excerpt]
        y = targets[excerpt] 
        for  xxt,yyt in datagen.flow(x, y , batch_size=x.shape[0]):
            x = xxt.astype(np.float32) 
            y = yyt 
            break

    #yield x, np.array(y, dtype=np.uint8)         
    return x, np.array(y, dtype=np.uint8)         

X_train_aug,Y_train_aug=iterate_minibatches( X_train_r, Y_train_r , X_train_r.shape[0], shuffle=True)

# display sample image after augmentation
misc.disp_img_mask(X_train_r,Y_train_r,2,4)
# Out:
# array([168, 105,  29,   0, 136,  72,   0,  91])

# %%
# obtain contour centers
cXY=misc.contour2roi(Y_train_aug)

# %%
print 'training in progress ...'

experiment='roi'
# Direct the output to a log file and to screen
#loggerFileName = './output/logs'+'/log.txt'
#utils.initialize_logger(loggerFileName)

# checkpoint
# create numpy folder if does no exist
path2weights='./output/weights/'+experiment
if  not os.path.exists(path2weights):
    os.makedirs(path2weights)
    print 'weights folder created'
filepath=path2weights+"/fold"+str(foldnm)+"weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only='True',mode='min')


# Fit the model
start_time=time.time()
scores=[]
scores_train=[]
for e in range(params_train['nbepoch']):
    print 'epoch: %s' %e
    seed = np.random.randint(0, 999999)
    X_train_r,Y_train_r=misc.preprocess(X_train,Y_train,params_preprocess)
    X_train_aug,Y_train_aug=iterate_minibatches( X_train_r, Y_train_r , X_train_r.shape[0], shuffle=True)
    y_train_aug=misc.contour2roi(Y_train_aug)/50    
    y_test_r=misc.contour2roi(Y_test_r)/50    
    model.fit(X_train_aug, y_train_aug, validation_data=(X_test_r, y_test_r), nb_epoch=1, batch_size=32,verbose=1,shuffle=True,callbacks=[checkpoint])
    score=model.evaluate(X_test_r, y_test_r)    
    score_train=model.evaluate(X_train_aug, y_train_aug)    
    scores=np.append(scores,score)
    scores_train=np.append(scores_train,score_train)    
    

print 'model was trained!'
elapsed_time=(time.time()-start_time)/60
print 'elapsed time: %d  mins' %elapsed_time
# Out:
# training in progress ...
# epoch: 0
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0319Epoch 00000: val_loss improved from inf to 0.02694, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0312 - val_loss: 0.0269
# 186/186 [==============================] - 0s
# epoch: 1
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0232Epoch 00000: val_loss improved from 0.02694 to 0.01458, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0243 - val_loss: 0.0146
# 160/186 [========================>.....] - ETA: 0sepoch: 2
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0286Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0283 - val_loss: 0.0181
#  32/186 [====>.........................] - ETA: 0sepoch: 3
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0240Epoch 00000: val_loss improved from 0.01458 to 0.01356, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0235 - val_loss: 0.0136
# 186/186 [==============================] - 0s
# epoch: 4
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0279Epoch 00000: val_loss improved from 0.01356 to 0.01297, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0284 - val_loss: 0.0130
# 160/186 [========================>.....] - ETA: 0sepoch: 5
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0150Epoch 00000: val_loss improved from 0.01297 to 0.01182, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0165 - val_loss: 0.0118
# 186/186 [==============================] - 0s
# epoch: 6
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0297Epoch 00000: val_loss improved from 0.01182 to 0.01181, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0270 - val_loss: 0.0118
# 186/186 [==============================] - 0s
# epoch: 7
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0216Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0189 - val_loss: 0.0123
# 160/186 [========================>.....] - ETA: 0sepoch: 8
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0266Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0254 - val_loss: 0.0123
#  32/186 [====>.........................] - ETA: 0sepoch: 9
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0182Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0194 - val_loss: 0.0123
#  32/186 [====>.........................] - ETA: 0sepoch: 10
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0203Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0195 - val_loss: 0.0125
#  32/186 [====>.........................] - ETA: 0sepoch: 11
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0250Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0228 - val_loss: 0.0125
# 186/186 [==============================] - 0s
# epoch: 12
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0176Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0205 - val_loss: 0.0122
#  32/186 [====>.........................] - ETA: 0sepoch: 13
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0236Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0219 - val_loss: 0.0120
#  32/186 [====>.........................] - ETA: 0sepoch: 14
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0260Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0228 - val_loss: 0.0122
#  32/186 [====>.........................] - ETA: 0sepoch: 15
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0156Epoch 00000: val_loss improved from 0.01181 to 0.01170, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0172 - val_loss: 0.0117
#  32/186 [====>.........................] - ETA: 0sepoch: 16
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0265Epoch 00000: val_loss improved from 0.01170 to 0.01078, saving model to ./output/weights/roi/fold1weights.hdf5
# 186/186 [==============================] - 0s - loss: 0.0236 - val_loss: 0.0108
#  32/186 [====>.........................] - ETA: 0sepoch: 17
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0167Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0177 - val_loss: 0.0108
# 186/186 [==============================] - 0s
# epoch: 18
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0189Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0176 - val_loss: 0.0111
#  32/186 [====>.........................] - ETA: 0sepoch: 19
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0183Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0194 - val_loss: 0.0136
#  32/186 [====>.........................] - ETA: 0sepoch: 20
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0157Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0172 - val_loss: 0.0118
#  32/186 [====>.........................] - ETA: 0sepoch: 21
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0210Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0182 - val_loss: 0.0130
#  32/186 [====>.........................] - ETA: 0sepoch: 22
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
#  96/186 [==============>...............] - ETA: 0s - loss: 0.0156Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0160 - val_loss: 0.0111
#  32/186 [====>.........................] - ETA: 0sepoch: 23
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0205Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0194 - val_loss: 0.0109
# 186/186 [==============================] - 0s
# epoch: 24
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0226Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0227 - val_loss: 0.0109
# 186/186 [==============================] - 0s
# epoch: 25
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 160/186 [========================>.....] - ETA: 0s - loss: 0.0238Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0239 - val_loss: 0.0113
# 186/186 [==============================] - 0s
# epoch: 26
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0242Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0200Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0192 - val_loss: 0.0105
#  32/186 [====>.........................] - ETA: 0sepoch: 104
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0189Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0221 - val_loss: 0.0105
#  32/186 [====>.........................] - ETA: 0sepoch: 105
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0170Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0140 - val_loss: 0.0107
#  32/186 [====>.........................] - ETA: 0sepoch: 106
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0244Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0224 - val_loss: 0.0109
#  32/186 [====>.........................] - ETA: 0sepoch: 107
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0123Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0124 - val_loss: 0.0110
#  32/186 [====>.........................] - ETA: 0sepoch: 108
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0180Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0162 - val_loss: 0.0110
#  32/186 [====>.........................] - ETA: 0sepoch: 109
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0132Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0138 - val_loss: 0.0109
#  32/186 [====>.........................] - ETA: 0sepoch: 110
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0163Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0180 - val_loss: 0.0108
#  32/186 [====>.........................] - ETA: 0sepoch: 111
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0157Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0173 - val_loss: 0.0108
#  32/186 [====>.........................] - ETA: 0sepoch: 112
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0227Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0196 - val_loss: 0.0106
#  32/186 [====>.........................] - ETA: 0sepoch: 113
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0160Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0189 - val_loss: 0.0107
#  32/186 [====>.........................] - ETA: 0sepoch: 114
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0143Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0116 - val_loss: 0.0105
#  32/186 [====>.........................] - ETA: 0sepoch: 115
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0190Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0185 - val_loss: 0.0105
#  32/186 [====>.........................] - ETA: 0sepoch: 116
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0128Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0115 - val_loss: 0.0104
#  32/186 [====>.........................] - ETA: 0sepoch: 117
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0155Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0156 - val_loss: 0.0109
#  32/186 [====>.........................] - ETA: 0sepoch: 118
# __________________________________________________
# please wait to resize images ...
# ('X_r size: ', (186, 1, 52, 52))
# ('Y_r size: ', (186, 1, 52, 52))
# ('Min and Max  X_r: ', -1.4498713, 7.7716193)
# ('Min and Max  Y_r: ', 0, 1)
# Elapsed time: 0 seconds
# __________________________________________________
# Train on 186 samples, validate on 57 samples
# Epoch 1/1
# 128/186 [===================>..........] - ETA: 0s - loss: 0.0141Epoch 00000: val_loss did not improve
# 186/186 [==============================] - 0s - loss: 0.0123 - val_loss: 0.0110
#  32/186 [====>.........................] - ETA: 0sepoch: 119
# __________________________________________________
# please wait to resize images ...

# %%
plt.plot(scores)
plt.plot(scores_train)
plt.title('train-validation progress')
plt.legend(('test','train'), loc = 'lower right')
plt.xlabel('epochs')
plt.ylabel('dice')

# %%
print 'please wait to test ...'
weights_path='./output/weights/fold'+str(foldnm)+"-new-weights.hdf5"
if os.path.isfile( weights_path):
    model.load_weights(weights_path)
    print 'weights loaded!'

# predic training data
print '-' *50
print 'please wait to test ...'
Y_train_pred=model.predict(X_train_r)
DM_train=misc.calc_dice(Y_train_r,Y_train_pred)
print 'Train data Dice Metric: %0.2f' %DM_train

# %%
# predic test data
print '-' *50
print 'please wait to test ...'
Y_test_pred=model.predict(X_test_r)
DM_test=misc.calc_dice(Y_test_r,Y_test_pred)
print 'Test data Dice Metric: %0.2f' %DM_test

# %%
# preprocess test data     
params_preprocess={
    'row' : 192,
    'col' : 192,
    'imr' : 1,
    'crop': True,
    'crop_type': 'center',
    'normalization':False,
    }
# preprocess test data
X_test_r,Y_test_r=misc.preprocess(X_test,Y_test,params_preprocess)
plt.figure(figsize=(15,30))
misc.disp_img_mask(X_test_r,Y_test_r+Y_test_pred,6,3)
