# %%
# comparing histograms of images from different machines

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline  
import cv2

# configure plotting
plt.rcParams['figure.figsize'] = (15, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray' 

print 'packages loaded!'
# Out:
# packages loaded!

# %%
# path to images
path2image='../dcom/TrainingSet/patient01/tif/P01-0080.tif'

# load image
img = cv2.imread(path2image,0)
print img.shape
print np.max(img)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)
plt.figure()
plt.subplot(221)
plt.imshow(img,cmap='Greys_r')
plt.title('original')
plt.subplot(222)
plt.imshow(cl1,cmap='Greys_r')
plt.title('original')
plt.title('adaptive equalized')


plt.subplot(223)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

plt.subplot(224)
hist,bins = np.histogram(cl1.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(cl1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')
# Out:
# (256, 216)
# 255

# %%
# path to images
path2image='../dcom/TrainingSet/patient01/tif/P01-0228.tif'


# load image
img = cv2.imread(path2image,0)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)
plt.figure()
plt.subplot(221)
plt.imshow(img,cmap='Greys_r')
plt.title('original')
plt.subplot(222)
plt.imshow(cl1,cmap='Greys_r')
plt.title('original')
plt.title('adaptive equalized')


plt.subplot(223)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

plt.subplot(224)
hist,bins = np.histogram(cl1.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(cl1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

# %%
# path to images
path2image='../dcom/TrainingSet/patient02/tif/P02-0040.tif'


# load image
img = cv2.imread(path2image,0)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)
plt.figure()
plt.subplot(221)
plt.imshow(img,cmap='Greys_r')
plt.title('original ')
plt.subplot(222)
plt.imshow(cl1,cmap='Greys_r')
plt.title('original')
plt.title('adaptive equalized')


plt.subplot(223)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

plt.subplot(224)
hist,bins = np.histogram(cl1.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(cl1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

# %%
# path to images
path2image='../dcom/TrainingSet/patient06/tif/P06-0040.tif'


# load image
img = cv2.imread(path2image,0)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)
plt.figure()
plt.subplot(221)
plt.imshow(img,cmap='Greys_r')
plt.title('original ')
plt.subplot(222)
plt.imshow(cl1,cmap='Greys_r')
plt.title('original')
plt.title('adaptive equalized')


plt.subplot(223)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')

plt.subplot(224)
hist,bins = np.histogram(cl1.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(cl1.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
#plt.ylim([0,10000])
plt.legend(('cdf','histogram'), loc = 'upper left')
#plt.show()
plt.title('histogram')
